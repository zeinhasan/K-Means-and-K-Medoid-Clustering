# %%
import pandas as pd

# %%
data1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Praktikum Data Mining/UTS/SNMPTN(Saintek)_UGM.csv")
data2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Praktikum Data Mining/UTS/SNMPTN(Soshum)_UGM.csv")

# %%
SNMPTNTotal_UGM = pd.concat([data1, data2], axis=0)

# %%
SNMPTNTotal_UGM
# Out:
#     NO     KODE                                          NAMA JENJANG  \
# 0    1  3611526                 MANAJEMEN INFORMASI KESEHATAN      D4
# 1    2  3611534            TEKNOLOGI REKAYASA PERANGKAT LUNAK      D4
# 2    3  3611542                    TEKNOLOGI REKAYASA ELEKTRO      D4
# 3    4  3611557  TEKNOLOGI REKAYASA INSTRUMENTASI DAN KONTROL      D4
# 4    5  3611565                   TEKNOLOGI REKAYASA INTERNET      D4
# ..  ..      ...                                           ...     ...
# 25  26  3612197          PEMBANGUNAN SOSIAL DAN KESEJAHTERAAN      S1
# 26  27  3612201                               ILMU KOMUNIKASI      S1
# 27  28  3612216                                     SOSIOLOGI      S1
# 28  29  3612224                                     PSIKOLOGI      S1
# 29  30  3612232                                    PARIWISATA      S1
#
#     DAYA TAMPUNG 2022  PEMINAT 2021 JENIS PORTOFOLIO
# 0                18.0       309.000        Tidak Ada
# ...

# %%
SNMPTNTotal_UGM.to_csv("SNMPTN(Total)_UGM.csv",index=False)
